# %% [markdown]
# ## 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set = pd.read_csv('../data_raw/diabetes.csv')

# %%
print(data_set.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# print(data_set)

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data_set.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data_set.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
cleaned_filepath = "../data_clean/cleaned_diabetes.csv"
data_set.to_csv(cleaned_filepath, index=False)

# %%
np.random.seed(89)

# %% [markdown]
# ### a

# %%
sample_data = data_set.sample(25)

# %%
population_mean_glucose = data_set['Glucose'].mean()
population_highest_glucose = data_set['Glucose'].max()

# %%
sample_mean_glucose = sample_data['Glucose'].mean()
sample_highest_glucose = sample_data['Glucose'].max()

# %%
colors = ["skyblue", "salmon"]
fig, ax = plt.subplots()
sns.barplot(x=['Population', 'Sample'], y=[population_mean_glucose, sample_mean_glucose], palette=colors, ax=ax)
ax.set_title('Mean Glucose Comparison: Population vs Sample')

plt.savefig('../results/mean_glucose_comparison_Population_vs_sample.png')
plt.show()
# Out:
# /var/folders/sx/821x_2t93zj9437z5pc0wmbh0000gn/T/ipykernel_26267/3233688286.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Population', 'Sample'], y=[population_mean_glucose, sample_mean_glucose], palette=colors, ax=ax)

# %%
colors = ["skyblue", "salmon"]
fig, ax = plt.subplots()
sns.barplot(x=['Population', 'Sample'], y=[population_highest_glucose, sample_highest_glucose], palette=colors, ax=ax)
ax.set_title('Highest Glucose Comparison: Population vs Sample')

plt.savefig('../results/highest_glucose_comparison_population_vs_sample.png')
plt.show()
# Out:
# /var/folders/sx/821x_2t93zj9437z5pc0wmbh0000gn/T/ipykernel_26267/1667087449.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Population', 'Sample'], y=[population_highest_glucose, sample_highest_glucose], palette=colors, ax=ax)

# %% [markdown]
# ### b

# %%
sample_data = data_set.sample(25)

# %%
population_98th_percentile_bmi = np.percentile(data_set['BMI'], 98)
sample_98th_percentile_bmi = np.percentile(sample_data['BMI'], 98)

# %%
colors = ["skyblue", "salmon"]
fig, ax = plt.subplots()
sns.barplot(x=['Population', 'Sample'], y=[population_98th_percentile_bmi, sample_98th_percentile_bmi], palette=colors, ax=ax)
ax.set_title('BMI Distribution at 98th Percentile: Population vs Sample')
plt.savefig('../results/BMI_distribution_at_98th_percentile:population_vs_Sample_bar_plot.png')
plt.show()
# Out:
# /var/folders/sx/821x_2t93zj9437z5pc0wmbh0000gn/T/ipykernel_26267/3997649589.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Population', 'Sample'], y=[population_98th_percentile_bmi, sample_98th_percentile_bmi], palette=colors, ax=ax)

# %%
colors = ["skyblue", "salmon"]
fig, ax = plt.subplots(figsize=(8, 4))
sns.violinplot(x='Outcome', y='BMI', data=data_set, palette=colors, ax=ax)
ax.set_title('BMI Distribution at 98th Percentile: Population vs Sample')
plt.savefig('../results/BMI_distribution_at_98th_percentile:population_vs_sample_violin_plot.png')
plt.show()
# Out:
# /var/folders/sx/821x_2t93zj9437z5pc0wmbh0000gn/T/ipykernel_26267/4132027552.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Outcome', y='BMI', data=data_set, palette=colors, ax=ax)

# %%
colors = ["skyblue", "salmon"]
fig, ax = plt.subplots(figsize=(8, 4))
sns.barplot(x=[population_98th_percentile_bmi, sample_98th_percentile_bmi], y=['Population', 'Sample'], orient='h', palette=colors)
ax.set_title('BMI Distribution at 98th Percentile: Population vs Sample')
plt.savefig('../results/BMI_distribution_at_98th_percentile:population_vs_sample_horizontal_bar_plot.png')
plt.show()
# Out:
# /var/folders/sx/821x_2t93zj9437z5pc0wmbh0000gn/T/ipykernel_26267/2346212146.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=[population_98th_percentile_bmi, sample_98th_percentile_bmi], y=['Population', 'Sample'], orient='h', palette=colors)

# %% [markdown]
# ### C

# %%
bootstrap_means = []
bootstrap_standarddeviations = []
bootstrap_percentiles = []

# %%
for x in range(500):
    bootstrap_sample = data_set.sample(150, replace=True)
    bootstrap_mean = bootstrap_sample['BloodPressure'].mean()
    bootstrap_std = bootstrap_sample['BloodPressure'].std()
    bootstrap_percentile = np.percentile(bootstrap_sample['BloodPressure'], 95)
    bootstrap_means.append(bootstrap_mean)
    bootstrap_standarddeviations.append(bootstrap_std)
    bootstrap_percentiles.append(bootstrap_percentile)
bootstrap_stats = pd.DataFrame({
    'Mean': bootstrap_means,
    'Std': bootstrap_standarddeviations,
    'Percentile': bootstrap_percentiles
})

# %%
population_mean_blood_pressure = data_set['BloodPressure'].mean()
population_standarddeviation_blood_pressure = data_set['BloodPressure'].std()
population_percentile_blood_pressure = np.percentile(data_set['BloodPressure'], 95)

# %%
print('Population Mean: ', population_mean_blood_pressure)
# Out:
# Population Mean:  69.10546875

# %%
print('Bootstrap Mean: ', bootstrap_mean)
# Out:
# Bootstrap Mean:  65.93333333333334

# %%
print('Population Standard Deviation: ', population_standarddeviation_blood_pressure)
# Out:
# Population Standard Deviation:  19.355807170644777

# %%
print('Bootstrap Standard Deviation: ', bootstrap_std)
# Out:
# Bootstrap Standard Deviation:  20.408468654976623

# %%
print('Population Percentile: ', population_percentile_blood_pressure)
# Out:
# Population Percentile:  90.0

# %%
print('Bootstrap Percentile: ', bootstrap_percentile)
# Out:
# Bootstrap Percentile:  88.0

# %%
labels = ['Population Mean', 'Bootstrap Sample Mean', 'Population Std Dev', 'Bootstrap Sample Std Dev', 'Population 95th Percentile', 'Bootstrap Sample 95th Percentile']
values = [population_mean_blood_pressure, np.mean(bootstrap_mean), population_standarddeviation_blood_pressure, np.mean(bootstrap_std), population_percentile_blood_pressure, np.mean(bootstrap_percentile)]
plt.figure(figsize=(18, 9))
plt.bar(labels, values, color=['skyblue', 'salmon', 'skyblue', 'salmon', 'skyblue', 'salmon'])
plt.title('Comparing Blood Pressure Statistics: Population vs Bootstrap Samples')
plt.xlabel('Statistics')
plt.ylabel('BloodPressure values')
plt.savefig('../results/Comparing_blood_pressure_statistics:population_vs_bootstrap_samples_bar_plot.png')
plt.show()
